# %%
cd C:\Users\akanksh.belchada\Desktop\www.guvi.in
# Out:
# C:\Users\akanksh.belchada\Desktop\www.guvi.in

# %%
ls
# Out:
#  Volume in drive C is OSDisk
#  Volume Serial Number is AE33-482B
#
#  Directory of C:\Users\akanksh.belchada\Desktop\www.guvi.in
#
# 01/30/2021  11:26 AM    <DIR>          .
# 01/30/2021  11:26 AM    <DIR>          ..
# 01/30/2021  03:01 AM    <DIR>          .ipynb_checkpoints
# 01/14/2021  01:53 AM    <DIR>          __pycache__
# 01/30/2021  11:10 AM            37,050 GUVI01_MorePythonBasics.ipynb
# 01/30/2021  11:26 AM             2,503 MH.csv
# 01/17/2021  05:26 PM               228 my_csv.csv
# 01/17/2021  04:57 PM                16 myName.txt
# 01/17/2021  04:57 PM               124 myOwnPackage.py
# 01/23/2021  01:39 AM            96,519 Untitled.ipynb
#                6 File(s)        136,440 bytes
#                4 Dir(s)  118,428,540,928 bytes free

# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C is OSDisk
#  Volume Serial Number is AE33-482B
#
#  Directory of C:\Users\akanksh.belchada\Desktop\www.guvi.in
#
# 01/30/2021  11:26 AM    <DIR>          .
# 01/30/2021  11:26 AM    <DIR>          ..
# 01/30/2021  03:01 AM    <DIR>          .ipynb_checkpoints
# 01/14/2021  01:53 AM    <DIR>          __pycache__
# 01/30/2021  11:10 AM            37,050 GUVI01_MorePythonBasics.ipynb
# 01/30/2021  11:26 AM             2,503 MH.csv
# 01/17/2021  05:26 PM               228 my_csv.csv
# 01/17/2021  04:57 PM                16 myName.txt
# 01/17/2021  04:57 PM               124 myOwnPackage.py
# 01/23/2021  01:39 AM            96,519 Untitled.ipynb
#                6 File(s)        136,440 bytes
#                4 Dir(s)  118,428,540,928 bytes free

# %%
df=pd.read_csv('MH.csv')            #df is a common abbrevation for data feed

# %%
print(df)
# Out:
#              District/Municipal Corporation  COVID-19 cases  Deaths  \
# 0              Mumbai Municipal Corporation            1298      92
# 1               Thane Municipal Corporation              44       3
# 2    Kalyan-Dombivali Municipal Corporation              46       2
# 3          Ulhasnagar Municipal Corporation               1       0
# 4   Bhivandi-Nizampur Municipal Corporation               1       0
# ..                                      ...             ...     ...
# 66                                   Gondia               1       0
# 67                               Chandrapur               0       0
# 68                               Gadchiroli               0       0
# 69                             Other states               9       0
# 70                                    Total            1982     149
#
#            Type
# 0   Corporation
# 1   Corporation
# 2   Corporation
# 3   Corporation
# 4   Corporation
# ..          ...
# 66     District
# ...

# %%
df.head()                       # Prints the top 5 rows
# Out:
#             District/Municipal Corporation  COVID-19 cases  Deaths  \
# 0             Mumbai Municipal Corporation            1298      92
# 1              Thane Municipal Corporation              44       3
# 2   Kalyan-Dombivali Municipal Corporation              46       2
# 3         Ulhasnagar Municipal Corporation               1       0
# 4  Bhivandi-Nizampur Municipal Corporation               1       0
#
#           Type
# 0  Corporation
# 1  Corporation
# 2  Corporation
# 3  Corporation
# 4  Corporation

# %%
df.tail()                       #Prints the bottom 5 rows
# Out:
#    District/Municipal Corporation  COVID-19 cases  Deaths      Type
# 66                         Gondia               1       0  District
# 67                     Chandrapur               0       0  District
# 68                     Gadchiroli               0       0  District
# 69                   Other states               9       0  District
# 70                          Total            1982     149       NaN

# %%
dir(df)
# Out:
# ['Deaths',
#  'T',
#  'Type',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
# ...

# %%
len(df)                       # Shows the length of the data frame
# Out:
# 71

# %%
df.shape                           # Shape of the data frame
# Out:
# (71, 4)

# %%
print(len(df.loc[4]),"       \n   ", df.loc[4])                              #Loc is used for selecting subset of a row
# Out:
# 4
#     District/Municipal Corporation    Bhivandi-Nizampur Municipal Corporation
# COVID-19 cases                                                          1
# Deaths                                                                  0
# Type                                                          Corporation
# Name: 4, dtype: object

# %%
df_first_5_entries=df[1:6]
df_first_5_entries
# Out:
#             District/Municipal Corporation  COVID-19 cases  Deaths  \
# 1              Thane Municipal Corporation              44       3
# 2   Kalyan-Dombivali Municipal Corporation              46       2
# 3         Ulhasnagar Municipal Corporation               1       0
# 4  Bhivandi-Nizampur Municipal Corporation               1       0
# 5     Mira-Bhayandar Municipal Corporation              42       1
#
#           Type
# 1  Corporation
# 2  Corporation
# 3  Corporation
# 4  Corporation
# 5  Corporation

# %%
df_thin=df[['12-Apr','13-Apr']]
df_thin.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-158-0e7580919b1e> in <module>
# ----> 1 df_thin=df[['12-Apr','13-Apr']]
#       2 df_thin.shape
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ...

# %%
df[7:11]
# Out:
#       District/Municipal Corporation  COVID-19 cases  Deaths         Type
# 7       Panvel Municipal Corporation               8       1  Corporation
# 8       Nashik Municipal Corporation               1       0  Corporation
# 9     Malegaon Municipal Corporation              15       2  Corporation
# 10  Ahmednagar Municipal Corporation              16       0  Corporation

# %%
sf=df[7:11]

# %%
df
# Out:
#              District/Municipal Corporation  COVID-19 cases  Deaths  \
# 0              Mumbai Municipal Corporation            1298      92
# 1               Thane Municipal Corporation              44       3
# 2    Kalyan-Dombivali Municipal Corporation              46       2
# 3          Ulhasnagar Municipal Corporation               1       0
# 4   Bhivandi-Nizampur Municipal Corporation               1       0
# ..                                      ...             ...     ...
# 66                                   Gondia               1       0
# 67                               Chandrapur               0       0
# 68                               Gadchiroli               0       0
# 69                             Other states               9       0
# 70                                    Total            1982     149
#
#            Type
# 0   Corporation
# 1   Corporation
# 2   Corporation
# 3   Corporation
# 4   Corporation
# ..          ...
# 66     District
# ...

# %%
df['COVID-19 cases'].describe()           # Provides all the parameters
# Out:
# count      71.000000
# mean       83.619718
# std       328.904214
# min         0.000000
# 25%         1.000000
# 50%         4.000000
# 75%        18.500000
# max      1982.000000
# Name: COVID-19 cases, dtype: float64

# %%
x=df[df['Deaths']>10]['COVID-19 cases'].max()
x
# Out:
# 1982

# %%
g=df.groupby(['Type']).max()
# Out:
#                 District/Municipal Corporation  COVID-19 cases  Deaths
# Type
# Corporation  Vasai-Virar Municipal Corporation            1298      92
# District                              Yavatmal            1520     106

# %%
for key,val in g:
    print(key)
    print(val)
# Out:
# Corporation
#                District/Municipal Corporation  COVID-19 cases  Deaths  \
# 0                Mumbai Municipal Corporation            1298      92
# 1                 Thane Municipal Corporation              44       3
# 2      Kalyan-Dombivali Municipal Corporation              46       2
# 3            Ulhasnagar Municipal Corporation               1       0
# 4     Bhivandi-Nizampur Municipal Corporation               1       0
# 5        Mira-Bhayandar Municipal Corporation              42       1
# 6           Vasai-Virar Municipal Corporation              21       3
# 7                Panvel Municipal Corporation               8       1
# 8                Nashik Municipal Corporation               1       0
# 9              Malegaon Municipal Corporation              15       2
# 10           Ahmednagar Municipal Corporation              16       0
# 11                Dhule Municipal Corporation               0       0
# ...

# %%
df.groupby(['Type']).describe()
# Out:
#             COVID-19 cases                                              \
#                      count       mean         std  min  25%  50%   75%
# Type
# Corporation           27.0  69.222222  249.639792  0.0  1.0  8.0  25.0
# District              43.0  48.511628  233.487674  0.0  0.5  2.0   9.5
#
#                     Deaths
#                 max  count      mean        std  min  25%  50%  75%    max
# Type
# Corporation  1298.0   27.0  5.259259  18.249537  0.0  0.0  1.0  1.5   92.0
# District     1520.0   43.0  3.581395  16.764805  0.0  0.0  0.0  1.0  106.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ax=sns.pairplot(df,diag_kind='hist',hue='Type')

# %%
df
# Out:
#              District/Municipal Corporation  COVID-19 cases  Deaths  \
# 0              Mumbai Municipal Corporation            1298      92
# 1               Thane Municipal Corporation              44       3
# 2    Kalyan-Dombivali Municipal Corporation              46       2
# 3          Ulhasnagar Municipal Corporation               1       0
# 4   Bhivandi-Nizampur Municipal Corporation               1       0
# ..                                      ...             ...     ...
# 66                                   Gondia               1       0
# 67                               Chandrapur               0       0
# 68                               Gadchiroli               0       0
# 69                             Other states               9       0
# 70                                    Total            1982     149
#
#            Type
# 0   Corporation
# 1   Corporation
# 2   Corporation
# 3   Corporation
# 4   Corporation
# ..          ...
# 66     District
# ...

# %%
g=df.groupby(['Type']).sum()

# %%
g
# Out:
#              COVID-19 cases  Deaths
# Type
# Corporation            1869     142
# District               2086     154

# %%
def factorial(num):
    if num==0:
        return 1
    return num*factorial(num-1)

# %%
def code_to_debug():
    import random
    import pdb; pdb.set_trace()
    for i in range(1):
        x=random.random()
        print(x,factorial(x))

# %%
code_to_debug()
# Out:
# > <ipython-input-225-d4dbea94bf91>(4)code_to_debug()
# -> for i in range(1):
# (Pdb) step
# > <ipython-input-225-d4dbea94bf91>(5)code_to_debug()
# -> x=random.random()
# (Pdb) step
# > <ipython-input-225-d4dbea94bf91>(6)code_to_debug()
# -> print(x,factorial(x))
# (Pdb) s
# --Call--
# > <ipython-input-218-faa1af552460>(1)factorial()
# -> def factorial(num):
# (Pdb) s
# > <ipython-input-218-faa1af552460>(2)factorial()
# -> if num==0:
# (Pdb) s
# > <ipython-input-218-faa1af552460>(4)factorial()
# -> return num*factorial(num-1)
# (Pdb) s
# --Call--
# > <ipython-input-218-faa1af552460>(1)factorial()
# -> def factorial(num):
# (Pdb) s
# > <ipython-input-218-faa1af552460>(2)factorial()
# -> if num==0:
# (Pdb) s
# > <ipython-input-218-faa1af552460>(4)factorial()
# -> return num*factorial(num-1)
